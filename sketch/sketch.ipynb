# %%
# !pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.19.0-py2.py3-none-any.whl (9.6 MB)
#      ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#      ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#      ---------------------------------------- 0.0/9.6 MB 435.7 kB/s eta 0:00:22
#      ---------------------------------------- 0.0/9.6 MB 435.7 kB/s eta 0:00:22
#      ---------------------------------------- 0.0/9.6 MB 435.7 kB/s eta 0:00:22
#      ---------------------------------------- 0.0/9.6 MB 435.7 kB/s eta 0:00:22
#      ---------------------------------------- 0.1/9.6 MB 192.5 kB/s eta 0:00:50
#      ---------------------------------------- 0.1/9.6 MB 261.7 kB/s eta 0:00:37
#      ---------------------------------------- 0.1/9.6 MB 311.2 kB/s eta 0:00:31
#      ---------------------------------------- 0.1/9.6 MB 311.2 kB/s eta 0:00:31
#      ---------------------------------------- 0.1/9.6 MB 311.2 kB/s eta 0:00:31
#      ---------------------------------------- 0.1/9.6 MB 311.2 kB/s eta 0:00:31
#      ---------------------------------------- 0.1/9.6 MB 311.2 kB/s eta 0:00:31
#       --------------------------------------- 0.2/9.6 MB 345.6 kB/s eta 0:00:28
#       --------------------------------------- 0.2/9.6 MB 345.6 kB/s eta 0:00:28
#       --------------------------------------- 0.2/9.6 MB 345.6 kB/s eta 0:00:28
#       --------------------------------------- 0.2/9.6 MB 345.6 kB/s eta 0:00:28
#       --------------------------------------- 0.2/9.6 MB 345.6 kB/s eta 0:00:28
#       --------------------------------------- 0.2/9.6 MB 345.6 kB/s eta 0:00:28
#       --------------------------------------- 0.2/9.6 MB 345.6 kB/s eta 0:00:28
#       --------------------------------------- 0.2/9.6 MB 345.6 kB/s eta 0:00:28
#       --------------------------------------- 0.2/9.6 MB 345.6 kB/s eta 0:00:28
#       --------------------------------------- 0.2/9.6 MB 345.6 kB/s eta 0:00:28
#       --------------------------------------- 0.2/9.6 MB 345.6 kB/s eta 0:00:28
#       --------------------------------------- 0.2/9.6 MB 345.6 kB/s eta 0:00:28
#       --------------------------------------- 0.2/9.6 MB 345.6 kB/s eta 0:00:28
#      - -------------------------------------- 0.4/9.6 MB 305.8 kB/s eta 0:00:31
#      - -------------------------------------- 0.4/9.6 MB 327.6 kB/s eta 0:00:29
#      - -------------------------------------- 0.4/9.6 MB 327.6 kB/s eta 0:00:29
#      - -------------------------------------- 0.4/9.6 MB 327.6 kB/s eta 0:00:29
#      - -------------------------------------- 0.4/9.6 MB 297.9 kB/s eta 0:00:31
#      - -------------------------------------- 0.5/9.6 MB 312.9 kB/s eta 0:00:30
#      -- ------------------------------------- 0.5/9.6 MB 338.0 kB/s eta 0:00:27
#      -- ------------------------------------- 0.5/9.6 MB 348.5 kB/s eta 0:00:27
#      -- ------------------------------------- 0.5/9.6 MB 348.5 kB/s eta 0:00:27
#      -- ------------------------------------- 0.6/9.6 MB 375.3 kB/s eta 0:00:24
#      -- ------------------------------------- 0.7/9.6 MB 395.5 kB/s eta 0:00:23
#      -- ------------------------------------- 0.7/9.6 MB 398.1 kB/s eta 0:00:23
#      -- ------------------------------------- 0.7/9.6 MB 398.1 kB/s eta 0:00:23
#      -- ------------------------------------- 0.7/9.6 MB 387.5 kB/s eta 0:00:23
#      --- ------------------------------------ 0.7/9.6 MB 403.1 kB/s eta 0:00:22
#      --- ------------------------------------ 0.8/9.6 MB 415.1 kB/s eta 0:00:22
#      --- ------------------------------------ 0.8/9.6 MB 431.6 kB/s eta 0:00:21
#      --- ------------------------------------ 0.9/9.6 MB 440.2 kB/s eta 0:00:20
#      --- ------------------------------------ 0.9/9.6 MB 447.0 kB/s eta 0:00:20
#      --- ------------------------------------ 1.0/9.6 MB 456.7 kB/s eta 0:00:19
#      ---- ----------------------------------- 1.0/9.6 MB 470.7 kB/s eta 0:00:19
#      ---- ----------------------------------- 1.1/9.6 MB 487.8 kB/s eta 0:00:18
#      ---- ----------------------------------- 1.1/9.6 MB 487.8 kB/s eta 0:00:18
#      ---- ----------------------------------- 1.1/9.6 MB 491.5 kB/s eta 0:00:18
#      ---- ----------------------------------- 1.2/9.6 MB 508.2 kB/s eta 0:00:17
#      ----- ---------------------------------- 1.2/9.6 MB 524.2 kB/s eta 0:00:16
#      ----- ---------------------------------- 1.3/9.6 MB 531.1 kB/s eta 0:00:16
#      ----- ---------------------------------- 1.3/9.6 MB 532.7 kB/s eta 0:00:16
#      ----- ---------------------------------- 1.4/9.6 MB 543.3 kB/s eta 0:00:16
#      ----- ---------------------------------- 1.4/9.6 MB 554.1 kB/s eta 0:00:15
#      ------ --------------------------------- 1.5/9.6 MB 563.8 kB/s eta 0:00:15
#      ------ --------------------------------- 1.5/9.6 MB 572.4 kB/s eta 0:00:15
#      ------ --------------------------------- 1.5/9.6 MB 570.4 kB/s eta 0:00:15
#      ------ --------------------------------- 1.6/9.6 MB 583.7 kB/s eta 0:00:14
#      ------ --------------------------------- 1.6/9.6 MB 592.3 kB/s eta 0:00:14
#      ------- -------------------------------- 1.7/9.6 MB 604.3 kB/s eta 0:00:14
#      ------- -------------------------------- 1.7/9.6 MB 604.9 kB/s eta 0:00:14
#      ------- -------------------------------- 1.8/9.6 MB 609.2 kB/s eta 0:00:13
#      ------- -------------------------------- 1.8/9.6 MB 616.9 kB/s eta 0:00:13
#      ------- -------------------------------- 1.9/9.6 MB 628.1 kB/s eta 0:00:13
#      -------- ------------------------------- 1.9/9.6 MB 634.9 kB/s eta 0:00:13
#      -------- ------------------------------- 2.0/9.6 MB 638.5 kB/s eta 0:00:12
#      -------- ------------------------------- 2.0/9.6 MB 642.3 kB/s eta 0:00:12
#      -------- ------------------------------- 2.1/9.6 MB 652.0 kB/s eta 0:00:12
#      -------- ------------------------------- 2.1/9.6 MB 661.7 kB/s eta 0:00:12
#      --------- ------------------------------ 2.2/9.6 MB 661.5 kB/s eta 0:00:12
#      --------- ------------------------------ 2.2/9.6 MB 667.6 kB/s eta 0:00:12
#      --------- ------------------------------ 2.3/9.6 MB 673.6 kB/s eta 0:00:11
#      --------- ------------------------------ 2.3/9.6 MB 682.3 kB/s eta 0:00:11
#      --------- ------------------------------ 2.4/9.6 MB 687.8 kB/s eta 0:00:11
#      ---------- ----------------------------- 2.4/9.6 MB 687.3 kB/s eta 0:00:11
#      ---------- ----------------------------- 2.5/9.6 MB 692.6 kB/s eta 0:00:11
#      ---------- ----------------------------- 2.5/9.6 MB 700.9 kB/s eta 0:00:11
#      ---------- ----------------------------- 2.6/9.6 MB 705.6 kB/s eta 0:00:10
#      ---------- ----------------------------- 2.6/9.6 MB 710.8 kB/s eta 0:00:10
#      ----------- ---------------------------- 2.7/9.6 MB 712.8 kB/s eta 0:00:10
#      ----------- ---------------------------- 2.7/9.6 MB 720.2 kB/s eta 0:00:10
#      ----------- ---------------------------- 2.8/9.6 MB 724.7 kB/s eta 0:00:10
#      ----------- ---------------------------- 2.8/9.6 MB 732.0 kB/s eta 0:00:10
#      ----------- ---------------------------- 2.9/9.6 MB 731.1 kB/s eta 0:00:10
#      ------------ --------------------------- 2.9/9.6 MB 735.3 kB/s eta 0:00:10
#      ------------ --------------------------- 3.0/9.6 MB 744.5 kB/s eta 0:00:09
#      ------------ --------------------------- 3.0/9.6 MB 746.0 kB/s eta 0:00:09
#      ------------ --------------------------- 3.1/9.6 MB 752.9 kB/s eta 0:00:09
#      ------------- -------------------------- 3.1/9.6 MB 753.8 kB/s eta 0:00:09
#      ------------- -------------------------- 3.2/9.6 MB 760.0 kB/s eta 0:00:09
#      ------------- -------------------------- 3.3/9.6 MB 763.8 kB/s eta 0:00:09
#      ------------- -------------------------- 3.3/9.6 MB 769.7 kB/s eta 0:00:09
#      ------------- -------------------------- 3.4/9.6 MB 770.8 kB/s eta 0:00:09
#      -------------- ------------------------- 3.4/9.6 MB 774.2 kB/s eta 0:00:08
#      -------------- ------------------------- 3.5/9.6 MB 777.6 kB/s eta 0:00:08
#      -------------- ------------------------- 3.5/9.6 MB 783.1 kB/s eta 0:00:08
#      -------------- ------------------------- 3.6/9.6 MB 786.3 kB/s eta 0:00:08
#      --------------- ------------------------ 3.6/9.6 MB 784.9 kB/s eta 0:00:08
#      --------------- ------------------------ 3.7/9.6 MB 792.6 kB/s eta 0:00:08
#      --------------- ------------------------ 3.7/9.6 MB 795.6 kB/s eta 0:00:08
#      --------------- ------------------------ 3.8/9.6 MB 800.7 kB/s eta 0:00:08
#      --------------- ------------------------ 3.8/9.6 MB 803.6 kB/s eta 0:00:08
#      ---------------- ----------------------- 3.9/9.6 MB 802.1 kB/s eta 0:00:08
#      ---------------- ----------------------- 3.9/9.6 MB 804.9 kB/s eta 0:00:08
#      ---------------- ----------------------- 4.0/9.6 MB 809.7 kB/s eta 0:00:07
#      ---------------- ----------------------- 4.0/9.6 MB 814.4 kB/s eta 0:00:07
#      ---------------- ----------------------- 4.1/9.6 MB 815.5 kB/s eta 0:00:07
#      ----------------- ---------------------- 4.1/9.6 MB 818.1 kB/s eta 0:00:07
#      ----------------- ---------------------- 4.2/9.6 MB 822.2 kB/s eta 0:00:07
#      ----------------- ---------------------- 4.2/9.6 MB 825.2 kB/s eta 0:00:07
#      ----------------- ---------------------- 4.3/9.6 MB 831.6 kB/s eta 0:00:07
#      ------------------ --------------------- 4.4/9.6 MB 829.4 kB/s eta 0:00:07
#      ------------------ --------------------- 4.4/9.6 MB 832.3 kB/s eta 0:00:07
#      ------------------ --------------------- 4.5/9.6 MB 836.5 kB/s eta 0:00:07
#      ------------------ --------------------- 4.5/9.6 MB 838.3 kB/s eta 0:00:07
#      ------------------- -------------------- 4.6/9.6 MB 842.8 kB/s eta 0:00:06
#      ------------------- -------------------- 4.6/9.6 MB 844.9 kB/s eta 0:00:06
#      ------------------- -------------------- 4.6/9.6 MB 843.4 kB/s eta 0:00:06
#      ------------------- -------------------- 4.7/9.6 MB 849.2 kB/s eta 0:00:06
#      ------------------- -------------------- 4.8/9.6 MB 853.0 kB/s eta 0:00:06
#      -------------------- ------------------- 4.8/9.6 MB 853.2 kB/s eta 0:00:06
#      -------------------- ------------------- 4.9/9.6 MB 852.7 kB/s eta 0:00:06
#      -------------------- ------------------- 4.9/9.6 MB 857.1 kB/s eta 0:00:06
#      -------------------- ------------------- 5.0/9.6 MB 860.7 kB/s eta 0:00:06
#      --------------------- ------------------ 5.1/9.6 MB 866.1 kB/s eta 0:00:06
#      --------------------- ------------------ 5.1/9.6 MB 864.5 kB/s eta 0:00:06
#      --------------------- ------------------ 5.1/9.6 MB 866.3 kB/s eta 0:00:06
#      --------------------- ------------------ 5.2/9.6 MB 869.8 kB/s eta 0:00:06
#      --------------------- ------------------ 5.3/9.6 MB 872.6 kB/s eta 0:00:05
#      ---------------------- ----------------- 5.3/9.6 MB 873.2 kB/s eta 0:00:05
#      ---------------------- ----------------- 5.3/9.6 MB 871.0 kB/s eta 0:00:05
#      ---------------------- ----------------- 5.4/9.6 MB 876.5 kB/s eta 0:00:05
#      ---------------------- ----------------- 5.5/9.6 MB 879.7 kB/s eta 0:00:05
#      ----------------------- ---------------- 5.5/9.6 MB 883.1 kB/s eta 0:00:05
#      ----------------------- ---------------- 5.6/9.6 MB 883.0 kB/s eta 0:00:05
#      ----------------------- ---------------- 5.6/9.6 MB 882.9 kB/s eta 0:00:05
#      ----------------------- ---------------- 5.7/9.6 MB 886.0 kB/s eta 0:00:05
#      ----------------------- ---------------- 5.7/9.6 MB 889.7 kB/s eta 0:00:05
#      ------------------------ --------------- 5.8/9.6 MB 892.8 kB/s eta 0:00:05
#      ------------------------ --------------- 5.8/9.6 MB 892.6 kB/s eta 0:00:05
#      ------------------------ --------------- 5.9/9.6 MB 891.9 kB/s eta 0:00:05
#      ------------------------ --------------- 5.9/9.6 MB 893.4 kB/s eta 0:00:05
#      ------------------------ --------------- 6.0/9.6 MB 896.3 kB/s eta 0:00:05
#      ------------------------- -------------- 6.0/9.6 MB 899.7 kB/s eta 0:00:04
#      ------------------------- -------------- 6.1/9.6 MB 900.1 kB/s eta 0:00:04
#      ------------------------- -------------- 6.1/9.6 MB 900.3 kB/s eta 0:00:04
#      ------------------------- -------------- 6.2/9.6 MB 903.1 kB/s eta 0:00:04
#      -------------------------- ------------- 6.3/9.6 MB 906.5 kB/s eta 0:00:04
#      -------------------------- ------------- 6.3/9.6 MB 907.7 kB/s eta 0:00:04
#      -------------------------- ------------- 6.3/9.6 MB 906.0 kB/s eta 0:00:04
#      -------------------------- ------------- 6.4/9.6 MB 908.7 kB/s eta 0:00:04
#      -------------------------- ------------- 6.5/9.6 MB 912.8 kB/s eta 0:00:04
#      --------------------------- ------------ 6.5/9.6 MB 914.1 kB/s eta 0:00:04
#      --------------------------- ------------ 6.6/9.6 MB 914.3 kB/s eta 0:00:04
#      --------------------------- ------------ 6.6/9.6 MB 913.5 kB/s eta 0:00:04
#      --------------------------- ------------ 6.7/9.6 MB 916.0 kB/s eta 0:00:04
#      ---------------------------- ----------- 6.7/9.6 MB 918.6 kB/s eta 0:00:04
#      ---------------------------- ----------- 6.8/9.6 MB 920.6 kB/s eta 0:00:04
#      ---------------------------- ----------- 6.8/9.6 MB 918.0 kB/s eta 0:00:04
#      ---------------------------- ----------- 6.9/9.6 MB 921.8 kB/s eta 0:00:03
#      ---------------------------- ----------- 6.9/9.6 MB 924.3 kB/s eta 0:00:03
#      ----------------------------- ---------- 7.0/9.6 MB 925.4 kB/s eta 0:00:03
#      ----------------------------- ---------- 7.1/9.6 MB 927.7 kB/s eta 0:00:03
#      ----------------------------- ---------- 7.1/9.6 MB 926.0 kB/s eta 0:00:03
#      ----------------------------- ---------- 7.1/9.6 MB 928.4 kB/s eta 0:00:03
#      ----------------------------- ---------- 7.2/9.6 MB 929.3 kB/s eta 0:00:03
#      ------------------------------ --------- 7.2/9.6 MB 932.2 kB/s eta 0:00:03
#      ------------------------------ --------- 7.3/9.6 MB 933.2 kB/s eta 0:00:03
#      ------------------------------ --------- 7.4/9.6 MB 932.3 kB/s eta 0:00:03
#      ------------------------------ --------- 7.4/9.6 MB 934.6 kB/s eta 0:00:03
#      ------------------------------- -------- 7.5/9.6 MB 937.2 kB/s eta 0:00:03
#      ------------------------------- -------- 7.5/9.6 MB 936.4 kB/s eta 0:00:03
#      ------------------------------- -------- 7.6/9.6 MB 937.3 kB/s eta 0:00:03
#      ------------------------------- -------- 7.6/9.6 MB 938.1 kB/s eta 0:00:03
#      -------------------------------- ------- 7.7/9.6 MB 941.5 kB/s eta 0:00:03
#      -------------------------------- ------- 7.7/9.6 MB 944.2 kB/s eta 0:00:02
#      -------------------------------- ------- 7.8/9.6 MB 943.8 kB/s eta 0:00:02
#      -------------------------------- ------- 7.8/9.6 MB 944.6 kB/s eta 0:00:02
#      -------------------------------- ------- 7.9/9.6 MB 945.4 kB/s eta 0:00:02
#      --------------------------------- ------ 7.9/9.6 MB 947.6 kB/s eta 0:00:02
#      --------------------------------- ------ 8.0/9.6 MB 948.4 kB/s eta 0:00:02
#      --------------------------------- ------ 8.0/9.6 MB 949.2 kB/s eta 0:00:02
#      --------------------------------- ------ 8.1/9.6 MB 949.9 kB/s eta 0:00:02
#      ---------------------------------- ----- 8.2/9.6 MB 951.3 kB/s eta 0:00:02
#      ---------------------------------- ----- 8.2/9.6 MB 953.8 kB/s eta 0:00:02
#      ---------------------------------- ----- 8.3/9.6 MB 954.6 kB/s eta 0:00:02
#      ---------------------------------- ----- 8.3/9.6 MB 955.3 kB/s eta 0:00:02
#      ---------------------------------- ----- 8.4/9.6 MB 955.5 kB/s eta 0:00:02
#      ----------------------------------- ---- 8.4/9.6 MB 957.4 kB/s eta 0:00:02
#      ----------------------------------- ---- 8.5/9.6 MB 959.9 kB/s eta 0:00:02
#      ----------------------------------- ---- 8.6/9.6 MB 960.5 kB/s eta 0:00:02
#      ----------------------------------- ---- 8.6/9.6 MB 961.2 kB/s eta 0:00:02
#      ------------------------------------ --- 8.7/9.6 MB 963.0 kB/s eta 0:00:01
#      ------------------------------------ --- 8.7/9.6 MB 964.8 kB/s eta 0:00:01
#      ------------------------------------ --- 8.8/9.6 MB 965.5 kB/s eta 0:00:01
#      ------------------------------------ --- 8.8/9.6 MB 966.2 kB/s eta 0:00:01
#      ------------------------------------- -- 8.9/9.6 MB 968.0 kB/s eta 0:00:01
#      ------------------------------------- -- 8.9/9.6 MB 969.7 kB/s eta 0:00:01
#      ------------------------------------- -- 9.0/9.6 MB 970.3 kB/s eta 0:00:01
#      ------------------------------------- -- 9.0/9.6 MB 971.5 kB/s eta 0:00:01
#      ------------------------------------- -- 9.1/9.6 MB 970.4 kB/s eta 0:00:01
#      -------------------------------------- - 9.2/9.6 MB 973.2 kB/s eta 0:00:01
#      -------------------------------------- - 9.2/9.6 MB 974.8 kB/s eta 0:00:01
#      -------------------------------------- - 9.3/9.6 MB 975.5 kB/s eta 0:00:01
#      -------------------------------------- - 9.3/9.6 MB 977.6 kB/s eta 0:00:01
#      ---------------------------------------  9.4/9.6 MB 977.7 kB/s eta 0:00:01
#      ---------------------------------------  9.5/9.6 MB 979.3 kB/s eta 0:00:01
#      ---------------------------------------  9.5/9.6 MB 980.9 kB/s eta 0:00:01
#      ---------------------------------------  9.6/9.6 MB 981.4 kB/s eta 0:00:01
#      ---------------------------------------  9.6/9.6 MB 983.0 kB/s eta 0:00:01
#      ---------------------------------------- 9.6/9.6 MB 978.9 kB/s eta 0:00:00
# Collecting gitpython!=3.1.19
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ---------------------------------------- 0.0/184.3 kB ? eta -:--:--
#      --------------- ----------------------- 71.7/184.3 kB 1.3 MB/s eta 0:00:01
#      ----------------------------- -------- 143.4/184.3 kB 1.7 MB/s eta 0:00:01
#      -------------------------------------- 184.3/184.3 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: click>=7.0 in c:\users\atulp\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (8.1.3)
# Requirement already satisfied: packaging>=14.1 in c:\users\atulp\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (23.0)
# Collecting semver
#   Downloading semver-2.13.0-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: pandas>=0.25 in c:\users\atulp\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (1.5.3)
# Collecting rich>=10.11.0
#   Downloading rich-13.3.1-py3-none-any.whl (239 kB)
#      ---------------------------------------- 0.0/239.0 kB ? eta -:--:--
#      ----------- --------------------------- 71.7/239.0 kB 2.0 MB/s eta 0:00:01
#      ---------------------- --------------- 143.4/239.0 kB 1.7 MB/s eta 0:00:01
#      ----------------------------------- -- 225.3/239.0 kB 1.5 MB/s eta 0:00:01
#      -------------------------------------- 239.0/239.0 kB 1.6 MB/s eta 0:00:00
# Collecting watchdog
#   Downloading watchdog-2.3.1-py3-none-win_amd64.whl (80 kB)
#      ---------------------------------------- 0.0/80.6 kB ? eta -:--:--
#      ----------------------------------- ---- 71.7/80.6 kB 1.3 MB/s eta 0:00:01
#      ---------------------------------------- 80.6/80.6 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.4 in c:\users\atulp\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (2.25.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\atulp\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (9.4.0)
# Collecting importlib-metadata>=1.4
#   Downloading importlib_metadata-6.0.0-py3-none-any.whl (21 kB)
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.8.0-py2.py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#       --------------------------------------- 0.1/4.7 MB 1.6 MB/s eta 0:00:03
#      - -------------------------------------- 0.1/4.7 MB 1.4 MB/s eta 0:00:04
#      - -------------------------------------- 0.2/4.7 MB 1.7 MB/s eta 0:00:03
#      -- ------------------------------------- 0.3/4.7 MB 1.6 MB/s eta 0:00:03
#      -- ------------------------------------- 0.3/4.7 MB 1.3 MB/s eta 0:00:04
#      --- ------------------------------------ 0.4/4.7 MB 1.4 MB/s eta 0:00:04
#      --- ------------------------------------ 0.4/4.7 MB 1.4 MB/s eta 0:00:04
#      ---- ----------------------------------- 0.5/4.7 MB 1.4 MB/s eta 0:00:04
#      ---- ----------------------------------- 0.5/4.7 MB 1.4 MB/s eta 0:00:03
#      ----- ---------------------------------- 0.6/4.7 MB 1.3 MB/s eta 0:00:04
#      ----- ---------------------------------- 0.7/4.7 MB 1.3 MB/s eta 0:00:04
#      ------ --------------------------------- 0.7/4.7 MB 1.4 MB/s eta 0:00:03
#      ------- -------------------------------- 0.8/4.7 MB 1.4 MB/s eta 0:00:03
#      ------- -------------------------------- 0.8/4.7 MB 1.3 MB/s eta 0:00:03
#      ------- -------------------------------- 0.9/4.7 MB 1.3 MB/s eta 0:00:03
#      -------- ------------------------------- 1.0/4.7 MB 1.4 MB/s eta 0:00:03
#      --------- ------------------------------ 1.1/4.7 MB 1.4 MB/s eta 0:00:03
#      --------- ------------------------------ 1.1/4.7 MB 1.4 MB/s eta 0:00:03
#      ---------- ----------------------------- 1.2/4.7 MB 1.4 MB/s eta 0:00:03
#      ---------- ----------------------------- 1.3/4.7 MB 1.4 MB/s eta 0:00:03
#      ----------- ---------------------------- 1.3/4.7 MB 1.4 MB/s eta 0:00:03
#      ----------- ---------------------------- 1.4/4.7 MB 1.4 MB/s eta 0:00:03
#      ------------ --------------------------- 1.4/4.7 MB 1.4 MB/s eta 0:00:03
#      ------------ --------------------------- 1.5/4.7 MB 1.4 MB/s eta 0:00:03
#      ------------- -------------------------- 1.6/4.7 MB 1.4 MB/s eta 0:00:03
#      -------------- ------------------------- 1.6/4.7 MB 1.4 MB/s eta 0:00:03
#      -------------- ------------------------- 1.7/4.7 MB 1.4 MB/s eta 0:00:03
#      --------------- ------------------------ 1.8/4.7 MB 1.4 MB/s eta 0:00:03
#      --------------- ------------------------ 1.9/4.7 MB 1.4 MB/s eta 0:00:03
#      ---------------- ----------------------- 1.9/4.7 MB 1.4 MB/s eta 0:00:03
#      ---------------- ----------------------- 2.0/4.7 MB 1.4 MB/s eta 0:00:02
#      ----------------- ---------------------- 2.1/4.7 MB 1.4 MB/s eta 0:00:02
#      ------------------ --------------------- 2.1/4.7 MB 1.4 MB/s eta 0:00:02
#      ------------------ --------------------- 2.2/4.7 MB 1.4 MB/s eta 0:00:02
#      ------------------- -------------------- 2.3/4.7 MB 1.4 MB/s eta 0:00:02
#      -------------------- ------------------- 2.4/4.7 MB 1.4 MB/s eta 0:00:02
#      -------------------- ------------------- 2.4/4.7 MB 1.4 MB/s eta 0:00:02
#      --------------------- ------------------ 2.5/4.7 MB 1.4 MB/s eta 0:00:02
#      --------------------- ------------------ 2.6/4.7 MB 1.4 MB/s eta 0:00:02
#      ---------------------- ----------------- 2.6/4.7 MB 1.4 MB/s eta 0:00:02
#      ----------------------- ---------------- 2.7/4.7 MB 1.4 MB/s eta 0:00:02
#      ----------------------- ---------------- 2.8/4.7 MB 1.4 MB/s eta 0:00:02
#      ------------------------ --------------- 2.9/4.7 MB 1.4 MB/s eta 0:00:02
#      ------------------------- -------------- 3.0/4.7 MB 1.5 MB/s eta 0:00:02
#      ------------------------- -------------- 3.0/4.7 MB 1.5 MB/s eta 0:00:02
#      -------------------------- ------------- 3.1/4.7 MB 1.5 MB/s eta 0:00:02
#      --------------------------- ------------ 3.2/4.7 MB 1.5 MB/s eta 0:00:02
#      --------------------------- ------------ 3.2/4.7 MB 1.5 MB/s eta 0:00:01
#      ---------------------------- ----------- 3.3/4.7 MB 1.5 MB/s eta 0:00:01
#      ----------------------------- ---------- 3.4/4.7 MB 1.5 MB/s eta 0:00:01
#      ----------------------------- ---------- 3.5/4.7 MB 1.5 MB/s eta 0:00:01
#      ------------------------------ --------- 3.6/4.7 MB 1.5 MB/s eta 0:00:01
#      ------------------------------- -------- 3.7/4.7 MB 1.5 MB/s eta 0:00:01
#      ------------------------------- -------- 3.8/4.7 MB 1.5 MB/s eta 0:00:01
#      -------------------------------- ------- 3.8/4.7 MB 1.5 MB/s eta 0:00:01
#      --------------------------------- ------ 3.9/4.7 MB 1.5 MB/s eta 0:00:01
#      ---------------------------------- ----- 4.0/4.7 MB 1.5 MB/s eta 0:00:01
#      ---------------------------------- ----- 4.1/4.7 MB 1.5 MB/s eta 0:00:01
#      ----------------------------------- ---- 4.2/4.7 MB 1.5 MB/s eta 0:00:01
#      ------------------------------------ --- 4.3/4.7 MB 1.5 MB/s eta 0:00:01
#      ------------------------------------- -- 4.4/4.7 MB 1.5 MB/s eta 0:00:01
#      ------------------------------------- -- 4.4/4.7 MB 1.5 MB/s eta 0:00:01
#      -------------------------------------- - 4.5/4.7 MB 1.5 MB/s eta 0:00:01
#      ---------------------------------------  4.6/4.7 MB 1.6 MB/s eta 0:00:01
#      ---------------------------------------  4.7/4.7 MB 1.6 MB/s eta 0:00:01
#      ---------------------------------------- 4.7/4.7 MB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: cachetools>=4.0 in c:\users\atulp\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (5.3.0)
# Collecting pyarrow>=4.0
#   Downloading pyarrow-11.0.0-cp310-cp310-win_amd64.whl (20.6 MB)
#      ---------------------------------------- 0.0/20.6 MB ? eta -:--:--
#      ---------------------------------------- 0.1/20.6 MB 2.4 MB/s eta 0:00:09
#      ---------------------------------------- 0.2/20.6 MB 2.4 MB/s eta 0:00:09
#       --------------------------------------- 0.3/20.6 MB 2.3 MB/s eta 0:00:09
#       --------------------------------------- 0.4/20.6 MB 2.6 MB/s eta 0:00:08
#       --------------------------------------- 0.5/20.6 MB 2.0 MB/s eta 0:00:10
#      - -------------------------------------- 0.6/20.6 MB 2.1 MB/s eta 0:00:10
#      - -------------------------------------- 0.7/20.6 MB 2.1 MB/s eta 0:00:10
#      - -------------------------------------- 0.8/20.6 MB 2.2 MB/s eta 0:00:09
#      - -------------------------------------- 0.9/20.6 MB 2.1 MB/s eta 0:00:10
#      - -------------------------------------- 1.0/20.6 MB 2.1 MB/s eta 0:00:10
#      -- ------------------------------------- 1.1/20.6 MB 2.1 MB/s eta 0:00:10
#      -- ------------------------------------- 1.2/20.6 MB 2.2 MB/s eta 0:00:09
#      -- ------------------------------------- 1.3/20.6 MB 2.2 MB/s eta 0:00:09
#      -- ------------------------------------- 1.4/20.6 MB 2.1 MB/s eta 0:00:10
#      -- ------------------------------------- 1.5/20.6 MB 2.1 MB/s eta 0:00:09
#      --- ------------------------------------ 1.6/20.6 MB 2.1 MB/s eta 0:00:09
#      --- ------------------------------------ 1.8/20.6 MB 2.2 MB/s eta 0:00:09
#      --- ------------------------------------ 1.8/20.6 MB 2.1 MB/s eta 0:00:09
#      --- ------------------------------------ 1.9/20.6 MB 2.2 MB/s eta 0:00:09
#      --- ------------------------------------ 2.0/20.6 MB 2.2 MB/s eta 0:00:09
#      ---- ----------------------------------- 2.2/20.6 MB 2.2 MB/s eta 0:00:09
#      ---- ----------------------------------- 2.3/20.6 MB 2.2 MB/s eta 0:00:09
#      ---- ----------------------------------- 2.3/20.6 MB 2.2 MB/s eta 0:00:09
#      ---- ----------------------------------- 2.5/20.6 MB 2.2 MB/s eta 0:00:09
#      ----- ---------------------------------- 2.6/20.6 MB 2.2 MB/s eta 0:00:09
#      ----- ---------------------------------- 2.7/20.6 MB 2.3 MB/s eta 0:00:08
#      ----- ---------------------------------- 2.8/20.6 MB 2.3 MB/s eta 0:00:08
#      ----- ---------------------------------- 2.9/20.6 MB 2.2 MB/s eta 0:00:08
#      ----- ---------------------------------- 3.1/20.6 MB 2.3 MB/s eta 0:00:08
#      ------ --------------------------------- 3.2/20.6 MB 2.3 MB/s eta 0:00:08
#      ------ --------------------------------- 3.3/20.6 MB 2.3 MB/s eta 0:00:08
#      ------ --------------------------------- 3.4/20.6 MB 2.3 MB/s eta 0:00:08
#      ------ --------------------------------- 3.5/20.6 MB 2.3 MB/s eta 0:00:08
#      ------- -------------------------------- 3.7/20.6 MB 2.3 MB/s eta 0:00:08
#      ------- -------------------------------- 3.8/20.6 MB 2.3 MB/s eta 0:00:08
#      ------- -------------------------------- 3.9/20.6 MB 2.4 MB/s eta 0:00:08
#      ------- -------------------------------- 4.0/20.6 MB 2.3 MB/s eta 0:00:08
#      -------- ------------------------------- 4.2/20.6 MB 2.4 MB/s eta 0:00:07
#      -------- ------------------------------- 4.3/20.6 MB 2.4 MB/s eta 0:00:07
#      -------- ------------------------------- 4.5/20.6 MB 2.4 MB/s eta 0:00:07
#      -------- ------------------------------- 4.6/20.6 MB 2.4 MB/s eta 0:00:07
#      --------- ------------------------------ 4.7/20.6 MB 2.4 MB/s eta 0:00:07
#      --------- ------------------------------ 4.8/20.6 MB 2.4 MB/s eta 0:00:07
#      --------- ------------------------------ 5.0/20.6 MB 2.4 MB/s eta 0:00:07
#      --------- ------------------------------ 5.1/20.6 MB 2.4 MB/s eta 0:00:07
#      ---------- ----------------------------- 5.2/20.6 MB 2.4 MB/s eta 0:00:07
#      ---------- ----------------------------- 5.4/20.6 MB 2.5 MB/s eta 0:00:07
#      ---------- ----------------------------- 5.6/20.6 MB 2.5 MB/s eta 0:00:07
#      ----------- ---------------------------- 5.7/20.6 MB 2.5 MB/s eta 0:00:06
#      ----------- ---------------------------- 5.8/20.6 MB 2.5 MB/s eta 0:00:06
#      ----------- ---------------------------- 5.9/20.6 MB 2.5 MB/s eta 0:00:06
#      ----------- ---------------------------- 6.1/20.6 MB 2.5 MB/s eta 0:00:06
#      ------------ --------------------------- 6.3/20.6 MB 2.6 MB/s eta 0:00:06
#      ------------ --------------------------- 6.4/20.6 MB 2.6 MB/s eta 0:00:06
#      ------------ --------------------------- 6.6/20.6 MB 2.6 MB/s eta 0:00:06
#      ------------- -------------------------- 6.7/20.6 MB 2.6 MB/s eta 0:00:06
#      ------------- -------------------------- 6.9/20.6 MB 2.6 MB/s eta 0:00:06
#      ------------- -------------------------- 7.0/20.6 MB 2.6 MB/s eta 0:00:06
#      -------------- ------------------------- 7.2/20.6 MB 2.6 MB/s eta 0:00:06
#      -------------- ------------------------- 7.3/20.6 MB 2.6 MB/s eta 0:00:06
#      -------------- ------------------------- 7.5/20.6 MB 2.6 MB/s eta 0:00:05
#      -------------- ------------------------- 7.7/20.6 MB 2.7 MB/s eta 0:00:05
#      --------------- ------------------------ 7.9/20.6 MB 2.7 MB/s eta 0:00:05
#      --------------- ------------------------ 8.0/20.6 MB 2.7 MB/s eta 0:00:05
#      --------------- ------------------------ 8.2/20.6 MB 2.7 MB/s eta 0:00:05
#      ---------------- ----------------------- 8.3/20.6 MB 2.7 MB/s eta 0:00:05
#      ---------------- ----------------------- 8.5/20.6 MB 2.7 MB/s eta 0:00:05
#      ---------------- ----------------------- 8.7/20.6 MB 2.8 MB/s eta 0:00:05
#      ----------------- ---------------------- 8.8/20.6 MB 2.8 MB/s eta 0:00:05
#      ----------------- ---------------------- 9.0/20.6 MB 2.8 MB/s eta 0:00:05
#      ----------------- ---------------------- 9.2/20.6 MB 2.8 MB/s eta 0:00:05
#      ------------------ --------------------- 9.4/20.6 MB 2.8 MB/s eta 0:00:04
#      ------------------ --------------------- 9.6/20.6 MB 2.8 MB/s eta 0:00:04
#      ------------------ --------------------- 9.7/20.6 MB 2.8 MB/s eta 0:00:04
#      ------------------- -------------------- 9.9/20.6 MB 2.8 MB/s eta 0:00:04
#      ------------------- -------------------- 10.1/20.6 MB 2.9 MB/s eta 0:00:04
#      -------------------- ------------------- 10.3/20.6 MB 2.9 MB/s eta 0:00:04
#      -------------------- ------------------- 10.5/20.6 MB 2.9 MB/s eta 0:00:04
#      -------------------- ------------------- 10.7/20.6 MB 3.0 MB/s eta 0:00:04
#      --------------------- ------------------ 10.9/20.6 MB 3.0 MB/s eta 0:00:04
#      --------------------- ------------------ 11.1/20.6 MB 3.0 MB/s eta 0:00:04
#      --------------------- ------------------ 11.3/20.6 MB 3.1 MB/s eta 0:00:03
#      ---------------------- ----------------- 11.5/20.6 MB 3.1 MB/s eta 0:00:03
#      ---------------------- ----------------- 11.7/20.6 MB 3.2 MB/s eta 0:00:03
#      ----------------------- ---------------- 11.9/20.6 MB 3.2 MB/s eta 0:00:03
#      ----------------------- ---------------- 12.1/20.6 MB 3.3 MB/s eta 0:00:03
#      ----------------------- ---------------- 12.3/20.6 MB 3.3 MB/s eta 0:00:03
#      ------------------------ --------------- 12.5/20.6 MB 3.3 MB/s eta 0:00:03
#      ------------------------ --------------- 12.7/20.6 MB 3.4 MB/s eta 0:00:03
#      ------------------------- -------------- 13.0/20.6 MB 3.4 MB/s eta 0:00:03
#      ------------------------- -------------- 13.2/20.6 MB 3.5 MB/s eta 0:00:03
#      -------------------------- ------------- 13.4/20.6 MB 3.5 MB/s eta 0:00:03
#      -------------------------- ------------- 13.6/20.6 MB 3.6 MB/s eta 0:00:02
#      -------------------------- ------------- 13.8/20.6 MB 3.6 MB/s eta 0:00:02
#      --------------------------- ------------ 14.1/20.6 MB 3.7 MB/s eta 0:00:02
#      --------------------------- ------------ 14.3/20.6 MB 3.7 MB/s eta 0:00:02
#      ---------------------------- ----------- 14.5/20.6 MB 3.8 MB/s eta 0:00:02
#      ---------------------------- ----------- 14.8/20.6 MB 3.8 MB/s eta 0:00:02
#      ----------------------------- ---------- 15.0/20.6 MB 3.9 MB/s eta 0:00:02
#      ----------------------------- ---------- 15.2/20.6 MB 3.9 MB/s eta 0:00:02
#      ------------------------------ --------- 15.5/20.6 MB 4.0 MB/s eta 0:00:02
#      ------------------------------ --------- 15.7/20.6 MB 4.0 MB/s eta 0:00:02
#      ------------------------------- -------- 15.9/20.6 MB 4.1 MB/s eta 0:00:02
#      ------------------------------- -------- 16.2/20.6 MB 4.1 MB/s eta 0:00:02
#      -------------------------------- ------- 16.5/20.6 MB 4.2 MB/s eta 0:00:01
#      -------------------------------- ------- 16.7/20.6 MB 4.2 MB/s eta 0:00:01
#      --------------------------------- ------ 17.0/20.6 MB 4.3 MB/s eta 0:00:01
#      --------------------------------- ------ 17.2/20.6 MB 4.3 MB/s eta 0:00:01
#      ---------------------------------- ----- 17.5/20.6 MB 4.4 MB/s eta 0:00:01
#      ---------------------------------- ----- 17.7/20.6 MB 4.5 MB/s eta 0:00:01
#      ---------------------------------- ----- 18.0/20.6 MB 4.5 MB/s eta 0:00:01
#      ----------------------------------- ---- 18.3/20.6 MB 4.6 MB/s eta 0:00:01
#      ------------------------------------ --- 18.5/20.6 MB 4.6 MB/s eta 0:00:01
#      ------------------------------------ --- 18.8/20.6 MB 4.7 MB/s eta 0:00:01
#      ------------------------------------- -- 19.1/20.6 MB 4.7 MB/s eta 0:00:01
#      ------------------------------------- -- 19.3/20.6 MB 4.9 MB/s eta 0:00:01
#      -------------------------------------- - 19.6/20.6 MB 4.9 MB/s eta 0:00:01
#      -------------------------------------- - 19.9/20.6 MB 5.0 MB/s eta 0:00:01
#      ---------------------------------------  20.2/20.6 MB 5.0 MB/s eta 0:00:01
#      ---------------------------------------  20.4/20.6 MB 5.0 MB/s eta 0:00:01
#      ---------------------------------------  20.5/20.6 MB 5.1 MB/s eta 0:00:01
#      ---------------------------------------  20.5/20.6 MB 5.1 MB/s eta 0:00:01
#      ---------------------------------------- 20.6/20.6 MB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.10.0.0 in c:\users\atulp\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (4.4.0)
# Requirement already satisfied: python-dateutil in c:\users\atulp\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: tornado>=6.0.3 in c:\users\atulp\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (6.2)
# Collecting pympler>=0.9
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#      ---------------------------------------- 0.0/164.8 kB ? eta -:--:--
#      -------------------------------------- 164.8/164.8 kB 5.0 MB/s eta 0:00:00
# Collecting blinker>=1.0.0
#   Downloading blinker-1.5-py2.py3-none-any.whl (12 kB)
# Collecting altair>=3.2.0
#   Downloading altair-4.2.2-py3-none-any.whl (813 kB)
#      ---------------------------------------- 0.0/813.6 kB ? eta -:--:--
#      --------------- --------------------- 337.9/813.6 kB 10.6 MB/s eta 0:00:01
#      -------------------------------- ----- 696.3/813.6 kB 8.8 MB/s eta 0:00:01
#      -------------------------------------- 813.6/813.6 kB 7.4 MB/s eta 0:00:00
# Collecting tzlocal>=1.1
#   Downloading tzlocal-4.2-py3-none-any.whl (19 kB)
# Requirement already satisfied: protobuf<4,>=3.12 in c:\users\atulp\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (3.19.6)
# Requirement already satisfied: numpy in c:\users\atulp\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (1.24.2)
# Collecting toml
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Collecting validators>=0.2
#   Downloading validators-0.20.0.tar.gz (30 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting toolz
#   Downloading toolz-0.12.0-py3-none-any.whl (55 kB)
#      ---------------------------------------- 0.0/55.8 kB ? eta -:--:--
#      ---------------------------------------- 55.8/55.8 kB ? eta 0:00:00
# Requirement already satisfied: jinja2 in c:\users\atulp\appdata\local\programs\python\python310\lib\site-packages (from altair>=3.2.0->streamlit) (3.1.2)
# Collecting entrypoints
#   Downloading entrypoints-0.4-py3-none-any.whl (5.3 kB)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\atulp\appdata\local\programs\python\python310\lib\site-packages (from altair>=3.2.0->streamlit) (4.17.3)
# Requirement already satisfied: colorama in c:\users\atulp\appdata\local\programs\python\python310\lib\site-packages (from click>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/62.7 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/62.7 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/62.7 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/62.7 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/62.7 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/62.7 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/62.7 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/62.7 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/62.7 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/62.7 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/62.7 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/62.7 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/62.7 kB ? eta -:--:--
#      ------------------- ------------------- 30.7/62.7 kB 33.6 kB/s eta 0:00:01
#      ------------------- ------------------- 30.7/62.7 kB 33.6 kB/s eta 0:00:01
#      ------------------- ------------------- 30.7/62.7 kB 33.6 kB/s eta 0:00:01
#      ------------------- ------------------- 30.7/62.7 kB 33.6 kB/s eta 0:00:01
#      ------------------- ------------------- 30.7/62.7 kB 33.6 kB/s eta 0:00:01
#      ------------------- ------------------- 30.7/62.7 kB 33.6 kB/s eta 0:00:01
#      ------------------- ------------------- 30.7/62.7 kB 33.6 kB/s eta 0:00:01
#      --------------------------------------- 62.7/62.7 kB 56.9 kB/s eta 0:00:00
# Collecting zipp>=0.5
#   Downloading zipp-3.15.0-py3-none-any.whl (6.8 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\atulp\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.25->streamlit) (2022.7.1)
# Requirement already satisfied: six>=1.5 in c:\users\atulp\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil->streamlit) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\atulp\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.4->streamlit) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\atulp\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.4->streamlit) (1.26.14)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\atulp\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.4->streamlit) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\atulp\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.4->streamlit) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.14.0 in c:\users\atulp\appdata\local\programs\python\python310\lib\site-packages (from rich>=10.11.0->streamlit) (2.14.0)
# Collecting markdown-it-py<3.0.0,>=2.1.0
#   Downloading markdown_it_py-2.2.0-py3-none-any.whl (84 kB)
#      ---------------------------------------- 0.0/84.5 kB ? eta -:--:--
#      ---------------------------------------- 84.5/84.5 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: tzdata in c:\users\atulp\appdata\local\programs\python\python310\lib\site-packages (from tzlocal>=1.1->streamlit) (2022.7)
# Collecting pytz-deprecation-shim
#   Downloading pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: decorator>=3.4.0 in c:\users\atulp\appdata\local\programs\python\python310\lib\site-packages (from validators>=0.2->streamlit) (5.1.1)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\atulp\appdata\local\programs\python\python310\lib\site-packages (from jinja2->altair>=3.2.0->streamlit) (2.1.2)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\atulp\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (22.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\atulp\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (0.19.3)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Building wheels for collected packages: validators
#   Building wheel for validators (setup.py): started
#   Building wheel for validators (setup.py): finished with status 'done'
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19591 sha256=824655db05c9bd6fea79c5333a6671314491f5c2cfdf0abd70fb855605a1da3a
#   Stored in directory: c:\users\atulp\appdata\local\pip\cache\wheels\f2\ed\dd\d3a556ad245ef9dc570c6bcd2f22886d17b0b408dd3bbb9ac3
# Successfully built validators
# Installing collected packages: zipp, watchdog, validators, toolz, toml, smmap, semver, pytz-deprecation-shim, pympler, pyarrow, mdurl, entrypoints, blinker, tzlocal, pydeck, markdown-it-py, importlib-metadata, gitdb, rich, gitpython, altair, streamlit
# Successfully installed altair-4.2.2 blinker-1.5 entrypoints-0.4 gitdb-4.0.10 gitpython-3.1.31 importlib-metadata-6.0.0 markdown-it-py-2.2.0 mdurl-0.1.2 pyarrow-11.0.0 pydeck-0.8.0 pympler-1.0.1 pytz-deprecation-shim-0.1.0.post0 rich-13.3.1 semver-2.13.0 smmap-5.0.0 streamlit-1.19.0 toml-0.10.2 toolz-0.12.0 tzlocal-4.2 validators-0.20.0 watchdog-2.3.1 zipp-3.15.0

# %%
# !pip install matplotlib opencv-python numpy pillow
# Out:
# Requirement already satisfied: matplotlib in c:\users\atulp\appdata\local\programs\python\python310\lib\site-packages (3.6.3)
# Requirement already satisfied: opencv-python in c:\users\atulp\appdata\local\programs\python\python310\lib\site-packages (4.7.0.68)
# Requirement already satisfied: numpy in c:\users\atulp\appdata\local\programs\python\python310\lib\site-packages (1.24.2)
# Requirement already satisfied: pillow in c:\users\atulp\appdata\local\programs\python\python310\lib\site-packages (9.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\atulp\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\atulp\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\atulp\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\atulp\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\atulp\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\atulp\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\atulp\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: six>=1.5 in c:\users\atulp\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import base64
from io import BytesIO

import streamlit as st
import cv2
import numpy as np
from PIL import Image

import matplotlib.pyplot as plt

# %%
def get_image_download_link(img):
    """Generates a link allowing the PIL image to be downloaded
    in:  PIL image
    out: href string
    """
    buffered = BytesIO()
    img.save(buffered, format="JPEG")
    img_str = base64.b64encode(buffered.getvalue()).decode()
    href = f'<a href="data:file/jpg;base64,{img_str}" download ="result.jpg">Download result</a>'
    return href

# %%
def print_hi(name):
    # Use a breakpoint in the code line below to debug your script.
    st.title("CONVERT IMAGE INTO A COLOR PENCIL SKETCH")
    st.header("Upload your file")
    # color = st.color_picker('Pick A Color', '#00f900')
    # st.write('The current color is', color)
    uploaded_file = st.file_uploader("Choose a image file", type=['png', 'jpg'])

    if uploaded_file is not None:
        # Convert the file to an opencv image.

        file_bytes = np.asarray(bytearray(uploaded_file.read()), dtype=np.uint8)
        opencv_image = cv2.imdecode(file_bytes, 1)

        # Now do something with the image! For example, let's display it:
        st.image(uploaded_file)

        grey_img = cv2.cvtColor(opencv_image, cv2.COLOR_BGR2GRAY)

        # Invert Image
        invert_img = cv2.bitwise_not(grey_img)
        # invert_img=255-grey_img

        # Blur image
        blur_img = cv2.GaussianBlur(invert_img, (111, 111), 0)

        # Invert Blurred Image
        invblur_img = cv2.bitwise_not(blur_img)
        # invblur_img=255-blur_img

        # Sketch Image
        sketch_img = cv2.divide(grey_img, invblur_img, scale=256.0)

        dst_sketch, dst_color_sketch = cv2.pencilSketch(opencv_image, sigma_s=50, sigma_r=0.07, shade_factor=0.08)
        dst_water_color = cv2.stylization(opencv_image, sigma_s=50, sigma_r=0.0825)
        invert = cv2.bitwise_not(dst_sketch)

        option = st.selectbox(
            'Choose Your Preferred pattern',
            ('Pencil Sketch', 'Color Pencil', 'Water Color', 'Final Sketch'))

        if option == "Pencil Sketch":
            option = st.selectbox('Choose Your Preferred Color', ('Grey', 'Red', 'Green', 'Blue', 'Purple'))
            fig = plt.figure(figsize=(12, 5))
            img = plt.imshow(invert, cmap=option + 's'), plt.axis('off'), plt.title('Pencil-Sketch in ' + option,
                                                                                    size=20)
            st.pyplot(fig)
            # plt.imsave(img,fig)
            result = Image.fromarray(invert)
            st.markdown(get_image_download_link(result), unsafe_allow_html=True)

        # result = Image.fromarray(img)
        # st.markdown(get_image_download_link(result), unsafe_allow_html=True)

        if option == "Color Pencil":
            fig = plt.figure(figsize=(12, 5))
            result = cv2.cvtColor(dst_color_sketch, cv2.COLOR_BGR2RGB)
            plt.imshow(result), plt.axis('off'), plt.title(
                'Color Pencil-Sketch', size=20)
            st.pyplot(fig)
            result = Image.fromarray(result)
            st.markdown(get_image_download_link(result), unsafe_allow_html=True)

        if option == "Water Color":
            fig = plt.figure(figsize=(12, 5))
            result = cv2.cvtColor(dst_water_color, cv2.COLOR_BGR2RGB)
            plt.imshow(result), plt.axis('off'), plt.title(
                'Water Color Image', size=20)
            st.pyplot(fig)
            result = Image.fromarray(result)
            st.markdown(get_image_download_link(result), unsafe_allow_html=True)

        if option == "Final Sketch":
            st.image(sketch_img)
            result = Image.fromarray(sketch_img)
            st.markdown(get_image_download_link(result), unsafe_allow_html=True)

        # st.header("Data Application")

        # Save Sketch
        # cv2.imwrite('sketch.png', sketch_img)
        print('Hello1')
        # st.image(invert, cmap='Purples')
        # st.image(newimage)

        # st.download_button('Download binary file', sketch_img)
        img_file = "test"
        result = Image.fromarray(sketch_img)
        # st.markdown(get_image_download_link(result, img_file, 'Download ' + img_file), unsafe_allow_html=True)
        # st.image(result, caption=f"Image Predicted")
        # result = Image.fromarray(result)

        # st.markdown(get_image_download_link(result), unsafe_allow_html=True)

        # st.download_button('Download CSV', result, 'file/jpg')

# %%
print_hi('test')
# Out:
# 2023-02-28 19:24:01.619
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\atulp\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
